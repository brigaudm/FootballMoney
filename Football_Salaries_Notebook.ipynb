# %%
pip install pandas

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.5.3

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-23a8afad-d5e1-4aa6-a049-f20120db762e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-23a8afad-d5e1-4aa6-a049-f20120db762e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#df is just a variable. We could name it something else
df = pd.read_csv("football_salaries_2023_OUTPUT.csv")

# %%
#top 5 rows
df.head()
# Out:
#               name               club   status position position_detail  age  \
# 0  Kevin De Bruyne    Manchester City  Starter        F              AM   32
# 1   Erling Haaland    Manchester City  Starter        F              CF   23
# 2    Mohamed Salah          Liverpool  Starter        F              RW   31
# 3         Casemiro  Manchester United  Starter        M              DM   31
# 4   Raphaël Varane  Manchester United  Starter        D              CB   30
#
#    country  active   loan        signed  ... bonus_net_usd  total_gross_eur  \
# 0  Belgium    True  False   Apr 7, 2021  ...           NaN     € 47,922,060
# 1   Norway    True  False   Jul 1, 2022  ...  $ 16,714,126     € 89,853,863
# 2    Egypt    True  False   Jul 1, 2022  ...   $ 1,758,734     € 41,931,803
# 3   Brazil    True  False  Aug 22, 2022  ...   $ 3,517,469     € 62,897,704
# 4   France    True  False  Aug 14, 2021  ...           NaN     € 40,733,751
#
# ...

# %%
#shows you the size of the thing
df.shape
# Out:
# (565, 39)

# %%
#data types
df.info
# Out:
# <bound method DataFrame.info of                   name               club   status position position_detail  \
# 0      Kevin De Bruyne    Manchester City  Starter        F              AM
# 1       Erling Haaland    Manchester City  Starter        F              CF
# 2        Mohamed Salah          Liverpool  Starter        F              RW
# 3             Casemiro  Manchester United  Starter        M              DM
# 4       Raphaël Varane  Manchester United  Starter        D              CB
# ..                 ...                ...      ...      ...             ...
# 560  Philippe Coutinho        Aston Villa  Reserve        F              LW
# 561       Adama Traoré             Fulham  Reserve        F              RW
# 562        Luke Harris             Fulham  Reserve        F              AM
# 563    Emmanuel Dennis  Nottingham Forest  Reserve        F              CF
# 564      Calvin Bassey             Fulham  Reserve        D              CB
#
# ...

# %%
df.head(565)
# Out:
#                   name               club   status position position_detail  \
# 0      Kevin De Bruyne    Manchester City  Starter        F              AM
# 1       Erling Haaland    Manchester City  Starter        F              CF
# 2        Mohamed Salah          Liverpool  Starter        F              RW
# 3             Casemiro  Manchester United  Starter        M              DM
# 4       Raphaël Varane  Manchester United  Starter        D              CB
# ..                 ...                ...      ...      ...             ...
# 560  Philippe Coutinho        Aston Villa  Reserve        F              LW
# 561       Adama Traoré             Fulham  Reserve        F              RW
# 562        Luke Harris             Fulham  Reserve        F              AM
# 563    Emmanuel Dennis  Nottingham Forest  Reserve        F              CF
# 564      Calvin Bassey             Fulham  Reserve        D              CB
#
# ...

# %%
df.head(3)
# Out:
#               name             club   status position position_detail  age  \
# 0  Kevin De Bruyne  Manchester City  Starter        F              AM   32
# 1   Erling Haaland  Manchester City  Starter        F              CF   23
# 2    Mohamed Salah        Liverpool  Starter        F              RW   31
#
#    country  active   loan       signed  ... bonus_net_usd  total_gross_eur  \
# 0  Belgium    True  False  Apr 7, 2021  ...           NaN     € 47,922,060
# 1   Norway    True  False  Jul 1, 2022  ...  $ 16,714,126     € 89,853,863
# 2    Egypt    True  False  Jul 1, 2022  ...   $ 1,758,734     € 41,931,803
#
#   total_net_eur total_gross_gbp total_net_gbp total_gross_usd total_net_usd  \
# 0  € 26,357,133    £ 41,600,000  £ 22,880,000    $ 51,163,183  $ 28,139,750
# 1  € 49,442,664    £ 78,000,000  £ 42,920,000    $ 95,930,968  $ 52,786,630
# 2  € 23,062,491    £ 36,400,000  £ 20,020,000    $ 44,767,785  $ 24,622,282
#
#      release_eur    release_gbp    release_usd
# ...

# %%
df.age.mean()
# Out:
# 25.819469026548674

# %%
df.age.median()
# Out:
# 25.0

# %%
df.age.value_counts()
# Out:
# 26    54
# 23    52
# 24    50
# 25    46
# 27    40
# 22    40
# 28    36
# 21    34
# 30    34
# 29    31
# 20    28
# 31    28
# 32    19
# 19    18
# 18    14
# 33    13
# 34     8
# 35     8
# 38     4
# 36     4
# 37     2
# 39     1
# 17     1
# Name: age, dtype: int64

# %%
df.age.min()
# Out:
# 17

# %%
df.age.max()
# Out:
# 39

# %%
len(df)
# Out:
# 565

# %%
df[df.club == "Liverpool"]
# Out:
#                        name       club   status position position_detail  age  \
# 2             Mohamed Salah  Liverpool  Starter        F              RW   31
# 20          Virgil van Dijk  Liverpool  Starter        D              CB   32
# 25                   Thiago  Liverpool  Reserve        M              CM   32
# 37   Trent Alexander-Arnold  Liverpool  Starter        D              RB   24
# 50         Ryan Gravenberch  Liverpool  Reserve        M              CM   21
# 51                  Alisson  Liverpool  Starter        K              GK   30
# 54      Alexis Mac Allister  Liverpool  Starter        M              CM   24
# 59             Darwin Núñez  Liverpool  Reserve        F              CF   24
# 60               Diogo Jota  Liverpool  Reserve        F              LW   26
# 67               Cody Gakpo  Liverpool  Starter        F              CF   24
# 71       Dominik Szoboszlai  Liverpool  Starter        F              AM   22
# ...

# %%
df[df.club == "Liverpool"].age.mean()
# Out:
# 26.26086956521739

# %%
df[df.club == "Liverpool"].age.max()
# Out:
# 36

# %%
df[(df.club == "Liverpool") & (df.age == 36)]
# Out:
#        name       club   status position position_detail  age country  active  \
# 194  Adrián  Liverpool  Reserve        K              GK   36   Spain    True
#
#       loan        signed  ... bonus_net_usd  total_gross_eur total_net_eur  \
# 194  False  Jun 30, 2023  ...           NaN      € 3,594,155   € 1,981,393
#
#     total_gross_gbp total_net_gbp total_gross_usd total_net_usd release_eur  \
# 194     £ 3,120,000   £ 1,720,000     $ 3,837,239   $ 2,115,401         NaN
#
#     release_gbp release_usd
# 194         NaN         NaN
#
# [1 rows x 39 columns]

# %%
df.sort_values("annual_gross_eur")
# Out:
#                   name               club   status position position_detail  \
# 438      Ethan Horvath  Nottingham Forest  Reserve        K              GK
# 418         Ben Osborn   Sheffield United  Reserve        M              CM
# 419        Harry Arter  Nottingham Forest  Reserve        M              CM
# 420     Oliver Norwood   Sheffield United  Starter        M              CM
# 421        Ben Johnson           West Ham  Reserve        D              RB
# ..                 ...                ...      ...      ...             ...
# 560  Philippe Coutinho        Aston Villa  Reserve        F              LW
# 561       Adama Traoré             Fulham  Reserve        F              RW
# 562        Luke Harris             Fulham  Reserve        F              AM
# 563    Emmanuel Dennis  Nottingham Forest  Reserve        F              CF
# 564      Calvin Bassey             Fulham  Reserve        D              CB
#
# ...

# %%
df[df.club == "Liverpool"].sort_values("annual_gross_eur", ascending = False)
# Out:
#                        name       club   status position position_detail  age  \
# 446            Curtis Jones  Liverpool  Reserve        M              CM   22
# 50         Ryan Gravenberch  Liverpool  Reserve        M              CM   21
# 51                  Alisson  Liverpool  Starter        K              GK   30
# 54      Alexis Mac Allister  Liverpool  Starter        M              CM   24
# 59             Darwin Núñez  Liverpool  Reserve        F              CF   24
# 60               Diogo Jota  Liverpool  Reserve        F              LW   26
# 71       Dominik Szoboszlai  Liverpool  Starter        F              AM   22
# 67               Cody Gakpo  Liverpool  Starter        F              CF   24
# 504       Caoimhín Kelleher  Liverpool  Reserve        K              GK   24
# 98               Joel Matip  Liverpool  Starter        D              CB   32
# 97         Andrew Robertson  Liverpool  Starter        D              LB   29
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 565 entries, 0 to 564
# Data columns (total 39 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              565 non-null    object
#  1   club              565 non-null    object
#  2   status            565 non-null    object
#  3   position          565 non-null    object
#  4   position_detail   565 non-null    object
#  5   age               565 non-null    int64
#  6   country           565 non-null    object
#  7   active            565 non-null    bool
#  8   loan              565 non-null    bool
#  9   signed            565 non-null    object
#  10  expiration        565 non-null    object
#  11  years             565 non-null    int64
#  12  weekly_gross_eur  546 non-null    object
#  13  annual_gross_eur  546 non-null    object
#  14  weekly_net_eur    546 non-null    object
#  15  annual_net_eur    546 non-null    object
# ...
